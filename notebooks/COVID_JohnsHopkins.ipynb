# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# # Confirmados

# %%
# Bing
# url = 'https://raw.githubusercontent.com/microsoft/Bing-COVID-19-Data/master/data/Bing-COVID19-Data.csv'
# df = pd.read_csv(url)

# %%
# Johns Hopkins
url = 'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv'
df = pd.read_csv(url)

# %%
confirmed = df.groupby(['Country/Region']).sum()
confirmed = confirmed.drop(columns=['Lat', 'Long'])
confirmed.head()
# Out:
#                 1/22/20  1/23/20  1/24/20  ...  5/27/20  5/28/20  5/29/20
# Country/Region                             ...
# Afghanistan           0        0        0  ...    12456    13036    13659
# Albania               0        0        0  ...     1050     1076     1099
# Algeria               0        0        0  ...     8857     8997     9134
# Andorra               0        0        0  ...      763      763      764
# Angola                0        0        0  ...       71       74       81
#
# [5 rows x 129 columns]

# %% [markdown]
# # Mortes

# %%
url = 'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_deaths_global.csv'
df = pd.read_csv(url)

# %%
deaths = df.groupby(['Country/Region']).sum()
deaths = deaths.drop(columns=['Lat', 'Long'])
deaths.head()
# Out:
#                 1/22/20  1/23/20  1/24/20  ...  5/27/20  5/28/20  5/29/20
# Country/Region                             ...
# Afghanistan           0        0        0  ...      227      235      246
# Albania               0        0        0  ...       33       33       33
# Algeria               0        0        0  ...      623      630      638
# Andorra               0        0        0  ...       51       51       51
# Angola                0        0        0  ...        4        4        4
#
# [5 rows x 129 columns]

# %% [markdown]
# # Recuperados

# %%
url = 'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_recovered_global.csv'
df = pd.read_csv(url)

# %%
recovered = df.groupby(['Country/Region']).sum()
recovered = recovered.drop(columns=['Lat', 'Long'])
recovered.head()
# Out:
#                 1/22/20  1/23/20  1/24/20  ...  5/27/20  5/28/20  5/29/20
# Country/Region                             ...
# Afghanistan           0        0        0  ...     1138     1209     1259
# Albania               0        0        0  ...      812      823      851
# Algeria               0        0        0  ...     5129     5277     5422
# Andorra               0        0        0  ...      676      681      684
# Angola                0        0        0  ...       18       18       18
#
# [5 rows x 129 columns]

# %% [markdown]
# # Visualização

# %%
pais = 'Brazil'

# %%
# agrupado
fig, ax = plt.subplots(figsize=(8, 6))
sel = confirmed.loc[pais].T
sel.index = pd.to_datetime(sel.index)
sel.plot(ax=ax, label='Confirmados')
sel = deaths.loc[pais].T
sel.index = pd.to_datetime(sel.index)
sel.plot(ax=ax, label='Mortes')
sel = recovered.loc[pais].T
sel.index = pd.to_datetime(sel.index)
sel.plot(ax=ax, label='Recuperados')
plt.legend()
plt.grid()
plt.show()

# %%
# confirmados
fig, ax = plt.subplots(figsize=(8, 6))
sel = confirmed.loc[pais].T
sel.index = pd.to_datetime(sel.index)
sel.plot(ax=ax)
plt.show()

# %%
# mortes
fig, ax = plt.subplots(figsize=(8, 6))
sel = deaths.loc[pais].T
sel.index = pd.to_datetime(sel.index)
sel.plot(ax=ax)
plt.show()

# %%
# recuperados
fig, ax = plt.subplots(figsize=(8, 6))
sel = recovered.loc[pais].T
sel.index = pd.to_datetime(sel.index)
sel.plot(ax=ax)
plt.show()
